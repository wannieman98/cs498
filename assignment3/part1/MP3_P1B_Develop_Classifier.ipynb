# %% [markdown]
# # Assignment 3 Part 1: Developing Your Own Classifier

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
os.chdir("drive/My Drive/part1")
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline

# %%
# !sh download_data.sh

import shutil 
shutil.copyfile("VOCtrainval_06-Nov-2007.tar", "/content/VOCtrainval_06-Nov-2007.tar")
# !tar -xf "/content/VOCtrainval_06-Nov-2007.tar" -C "/content/" 
shutil.move("/content/VOCdevkit/", "/content/VOCdevkit_2007")

shutil.copyfile("VOCtest_06-Nov-2007.tar", "/content/VOCtest_06-Nov-2007.tar")
# !tar -xf "/content/VOCtest_06-Nov-2007.tar" -C "/content/" 
shutil.move("/content/VOCdevkit/VOC2007", "/content/VOCdevkit_2007/VOC2007test")
# Out:
# --2021-04-11 20:49:54--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  78.5MB/s    in 5.7s
#
# 2021-04-11 20:49:59 (77.2 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]
#
# --2021-04-11 20:51:01--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  73.2MB/s    in 7.0s
#
# 2021-04-11 20:51:08 (61.1 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]
# '/content/VOCdevkit_2007/VOC2007test'

# %% [markdown]
# # Part 1B: Design your own network
#
# In this notebook, your task is to create and train your own model for multi-label classification on VOC Pascal.
#
# ## What to do
# 1. You will make change on network architecture in ```classifier.py```.
# 2. You may also want to change other hyperparameters to assist your training to get a better performances. Hints will be given in the below instructions.
#
# ## What to submit
# Check the submission template for details what to submit.

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels) in enumerate(train_loader):
      images, labels = images.to(device), labels.to(device)
      optimizer.zero_grad()
      logits = classifier(images)
      loss = criterion(logits, labels)
      loss.backward()
      optimizer.step()
      losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %%
import time

def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
      start = time.time()
      print("Starting epoch number " + str(epoch))
      train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
      train_losses.append(train_loss)
      print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
      if(epoch%test_frequency==0 or epoch==1):
          mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
          train_mAPs.append(mAP_train)
          mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
          print('Evaluating classifier')
          print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
          val_losses.append(val_loss)
          val_mAPs.append(mAP_val)
      time_elapsed = time.time() - start
      print('Epcoh complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))    
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %% [markdown]
# # Developing Your Own Model

# %% [markdown]
# ### Goal
# To meet the benchmark for this assignment you will need to improve the network. Note you should have noticed pretrained Alenxt performs really well, but training Alexnet from scratch performs much worse. We hope you can design a better architecture over both the simple classifier and AlexNet to train from scratch.
#
# ### How to start
# You may take inspiration from other published architectures and architectures discussed in lecture. However, you are NOT allowed to use predefined models (e.g. models from torchvision) or use pretrained weights. Training must be done from scratch with your own custom model.
#
# #### Some hints
# There are a variety of different approaches you should try to improve performance from the simple classifier:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper
#     * Batch normalization: adding batch norm between layers will likely give you a significant performance increase
#     * Residual connections: as you increase the depth of your network, you will find that having residual connections like those in ResNet architectures will be helpful
# * Optimizer: Instead of plain SGD, you may want to add a learning rate schedule, add momentum, or use one of the other optimizers you have learned about like Adam. Check the `torch.optim` package for other optimizers
# * Data augmentation: You should use the `torchvision.transforms` module to try adding random resized crops and horizontal flips of the input data. Check `transforms.RandomResizedCrop` and `transforms.RandomHorizontalFlip` for this. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.
# * Epochs: Once you have found a generally good hyperparameter setting try training for more epochs
# * Loss function: You might want to add weighting to the `MultiLabelSoftMarginLoss` for classes that are less well represented or experiment with a different loss function
#
#
#
# #### Note
# We will soon be providing some initial expectations of mAP values as a function of epoch so you can get an early idea whether your implementation works without waiting a long time for training to converge.
#
# ### What to submit
# Submit your best model to Kaggle and save all plots for the writeup.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.RandomHorizontalFlip(),
            transforms.RandomResizedCrop(227),
            transforms.ToTensor(),
            normalize
        ])

test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

ds_train = VocDataset("/content/VOCdevkit_2007/VOC2007",'train',train_transform)
ds_val = VocDataset("/content/VOCdevkit_2007/VOC2007",'val',test_transform)
ds_test = VocDataset("/content/VOCdevkit_2007/VOC2007test",'test', test_transform)
# Out:
# /content/drive/My Drive/part1/voc_dataloader.py:137: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(box_indices),

# %%
num_epochs = 150
test_frequency = 50
batch_size = 64

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=batch_size, 
                                               shuffle=False,
                                               num_workers=1)

# %%
# TODO: Run your own classifier here
classifier = Classifier().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.1, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=3e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.288467675447464
# -------  Class: aeroplane        AP:   0.0839  -------
# -------  Class: bicycle          AP:   0.0512  -------
# -------  Class: bird             AP:   0.1199  -------
# -------  Class: boat             AP:   0.0488  -------
# -------  Class: bottle           AP:   0.0636  -------
# -------  Class: bus              AP:   0.0314  -------
# -------  Class: car              AP:   0.1429  -------
# -------  Class: cat              AP:   0.0802  -------
# -------  Class: chair            AP:   0.1422  -------
# -------  Class: cow              AP:   0.0279  -------
# -------  Class: diningtable      AP:   0.0783  -------
# -------  Class: dog              AP:   0.1105  -------
# -------  Class: horse            AP:   0.0578  -------
# -------  Class: motorbike        AP:   0.0651  -------
# -------  Class: person           AP:   0.4758  -------
# -------  Class: pottedplant      AP:   0.0584  -------
# -------  Class: sheep            AP:   0.0256  -------
# -------  Class: sofa             AP:   0.0985  -------
# -------  Class: train            AP:   0.0519  -------
# -------  Class: tvmonitor        AP:   0.0513  -------
# mAP: 0.0933
# Avg loss: 0.2594450946897268
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.09326675951270652
# Epcoh complete in 0m 51s
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2424401044845581
# Epcoh complete in 0m 18s
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.23726420104503632
# Epcoh complete in 0m 18s
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.23355810344219208
# Epcoh complete in 0m 18s
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.23661230504512787
# Epcoh complete in 0m 18s
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.23250935971736908
# Epcoh complete in 0m 18s
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.23053012788295746
# Epcoh complete in 0m 18s
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.2285318225622177
# Epcoh complete in 0m 18s
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.2271343320608139
# Epcoh complete in 0m 18s
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.22687280178070068
# Epcoh complete in 0m 18s
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.2316051721572876
# Epcoh complete in 0m 18s
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.23127296566963196
# Epcoh complete in 0m 18s
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.22944679856300354
# Epcoh complete in 0m 19s
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.22509346902370453
# Epcoh complete in 0m 18s
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.22527320683002472
# Epcoh complete in 0m 18s
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.22536344826221466
# Epcoh complete in 0m 18s
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.22254334390163422
# Epcoh complete in 0m 18s
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.22109396755695343
# Epcoh complete in 0m 18s
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.22167687118053436
# Epcoh complete in 0m 18s
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.22081194818019867
# Epcoh complete in 0m 18s
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.21932287514209747
# Epcoh complete in 0m 18s
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.21824458241462708
# Epcoh complete in 0m 19s
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.2199232131242752
# Epcoh complete in 0m 18s
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.22146716713905334
# Epcoh complete in 0m 19s
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.21945658326148987
# Epcoh complete in 0m 18s
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.2172551155090332
# Epcoh complete in 0m 18s
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.21613343060016632
# Epcoh complete in 0m 18s
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.21407859027385712
# Epcoh complete in 0m 18s
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.2155202180147171
# Epcoh complete in 0m 19s
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.2182619571685791
# Epcoh complete in 0m 18s
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.21375393867492676
# Epcoh complete in 0m 18s
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.21029679477214813
# Epcoh complete in 0m 18s
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.2122669667005539
# Epcoh complete in 0m 19s
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.21069613099098206
# Epcoh complete in 0m 18s
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.206282839179039
# Epcoh complete in 0m 19s
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.21180517971515656
# Epcoh complete in 0m 19s
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.20721936225891113
# Epcoh complete in 0m 19s
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.2080381214618683
# Epcoh complete in 0m 19s
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.20637083053588867
# Epcoh complete in 0m 19s
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.20607466995716095
# Epcoh complete in 0m 19s
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.20444560050964355
# Epcoh complete in 0m 18s
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.2025509923696518
# Epcoh complete in 0m 19s
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.20178039371967316
# Epcoh complete in 0m 19s
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.20289383828639984
# Epcoh complete in 0m 18s
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.1996690332889557
# Epcoh complete in 0m 19s
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.2040022611618042
# Epcoh complete in 0m 18s
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.20046523213386536
# Epcoh complete in 0m 19s
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.19951601326465607
# Epcoh complete in 0m 18s
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.20028991997241974
# Epcoh complete in 0m 19s
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.19957934319972992
# -------  Class: aeroplane        AP:   0.4577  -------
# -------  Class: bicycle          AP:   0.1223  -------
# -------  Class: bird             AP:   0.2187  -------
# -------  Class: boat             AP:   0.2763  -------
# -------  Class: bottle           AP:   0.1317  -------
# -------  Class: bus              AP:   0.1132  -------
# -------  Class: car              AP:   0.5076  -------
# -------  Class: cat              AP:   0.2689  -------
# -------  Class: chair            AP:   0.4122  -------
# -------  Class: cow              AP:   0.1099  -------
# -------  Class: diningtable      AP:   0.2818  -------
# -------  Class: dog              AP:   0.2246  -------
# -------  Class: horse            AP:   0.3616  -------
# -------  Class: motorbike        AP:   0.2287  -------
# -------  Class: person           AP:   0.6850  -------
# -------  Class: pottedplant      AP:   0.1223  -------
# -------  Class: sheep            AP:   0.1009  -------
# -------  Class: sofa             AP:   0.1838  -------
# -------  Class: train            AP:   0.2724  -------
# -------  Class: tvmonitor        AP:   0.2011  -------
# mAP: 0.2640
# Avg loss: 0.1991098191589117
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.26404914648369593
# Epcoh complete in 0m 54s
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.19655458629131317
# Epcoh complete in 0m 18s
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.19659772515296936
# Epcoh complete in 0m 19s
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.198927640914917
# Epcoh complete in 0m 19s
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.20081062614917755
# Epcoh complete in 0m 18s
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.19624558091163635
# Epcoh complete in 0m 19s
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.19634492695331573
# Epcoh complete in 0m 18s
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.19694863259792328
# Epcoh complete in 0m 18s
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.1938825100660324
# Epcoh complete in 0m 19s
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.1923023760318756
# Epcoh complete in 0m 19s
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.19208531081676483
# Epcoh complete in 0m 18s
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.1899431049823761
# Epcoh complete in 0m 18s
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.19083504378795624
# Epcoh complete in 0m 19s
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.18890778720378876
# Epcoh complete in 0m 19s
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.18762044608592987
# Epcoh complete in 0m 19s
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.18863479793071747
# Epcoh complete in 0m 19s
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.19014139473438263
# Epcoh complete in 0m 19s
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.19142232835292816
# Epcoh complete in 0m 18s
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.18651004135608673
# Epcoh complete in 0m 19s
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.1821897327899933
# Epcoh complete in 0m 18s
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.18316440284252167
# Epcoh complete in 0m 19s
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.18588699400424957
# Epcoh complete in 0m 19s
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.19597041606903076
# Epcoh complete in 0m 19s
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.18880772590637207
# Epcoh complete in 0m 19s
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.18619249761104584
# Epcoh complete in 0m 18s
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.18611492216587067
# Epcoh complete in 0m 19s
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.18657396733760834
# Epcoh complete in 0m 18s
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.1853865087032318
# Epcoh complete in 0m 18s
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.18017694354057312
# Epcoh complete in 0m 18s
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.1827937662601471
# Epcoh complete in 0m 18s
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.1828327625989914
# Epcoh complete in 0m 19s
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.18261849880218506
# Epcoh complete in 0m 19s
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.1785750836133957
# Epcoh complete in 0m 19s
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.17708396911621094
# Epcoh complete in 0m 18s
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.1819038987159729
# Epcoh complete in 0m 18s
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.18511711061000824
# Epcoh complete in 0m 19s
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.17945681512355804
# Epcoh complete in 0m 19s
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.1777712106704712
# Epcoh complete in 0m 19s
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.18063393235206604
# Epcoh complete in 0m 19s
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.17763982713222504
# Epcoh complete in 0m 19s
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.17420034110546112
# Epcoh complete in 0m 19s
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.17495159804821014
# Epcoh complete in 0m 19s
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.17435197532176971
# Epcoh complete in 0m 18s
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.17426495254039764
# Epcoh complete in 0m 19s
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.17262683808803558
# Epcoh complete in 0m 18s
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.17109103500843048
# Epcoh complete in 0m 19s
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.17045380175113678
# Epcoh complete in 0m 18s
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.17252027988433838
# Epcoh complete in 0m 19s
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.1748136729001999
# Epcoh complete in 0m 19s
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.1681264191865921
# Epcoh complete in 0m 18s
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.16937954723834991
# -------  Class: aeroplane        AP:   0.5729  -------
# -------  Class: bicycle          AP:   0.3523  -------
# -------  Class: bird             AP:   0.2849  -------
# -------  Class: boat             AP:   0.4183  -------
# -------  Class: bottle           AP:   0.1530  -------
# -------  Class: bus              AP:   0.2792  -------
# -------  Class: car              AP:   0.5971  -------
# -------  Class: cat              AP:   0.3508  -------
# -------  Class: chair            AP:   0.4855  -------
# -------  Class: cow              AP:   0.1724  -------
# -------  Class: diningtable      AP:   0.3466  -------
# -------  Class: dog              AP:   0.2821  -------
# -------  Class: horse            AP:   0.4996  -------
# -------  Class: motorbike        AP:   0.4936  -------
# -------  Class: person           AP:   0.7952  -------
# -------  Class: pottedplant      AP:   0.1833  -------
# -------  Class: sheep            AP:   0.1787  -------
# -------  Class: sofa             AP:   0.3125  -------
# -------  Class: train            AP:   0.4796  -------
# -------  Class: tvmonitor        AP:   0.3026  -------
# mAP: 0.3770
# Avg loss: 0.18182668797671794
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.37701183055354714
# Epcoh complete in 0m 53s
# Starting epoch number 101
# Loss for Training on Epoch 101 is 0.16895641386508942
# Epcoh complete in 0m 18s
# Starting epoch number 102
# Loss for Training on Epoch 102 is 0.16913604736328125
# Epcoh complete in 0m 19s
# Starting epoch number 103
# Loss for Training on Epoch 103 is 0.17342881858348846
# Epcoh complete in 0m 19s
# Starting epoch number 104
# Loss for Training on Epoch 104 is 0.17469468712806702
# Epcoh complete in 0m 19s
# Starting epoch number 105
# Loss for Training on Epoch 105 is 0.17146313190460205
# Epcoh complete in 0m 19s
# Starting epoch number 106
# Loss for Training on Epoch 106 is 0.16453710198402405
# Epcoh complete in 0m 19s
# Starting epoch number 107
# Loss for Training on Epoch 107 is 0.1674082726240158
# Epcoh complete in 0m 19s
# Starting epoch number 108
# Loss for Training on Epoch 108 is 0.1657295525074005
# Epcoh complete in 0m 19s
# Starting epoch number 109
# Loss for Training on Epoch 109 is 0.1683768332004547
# Epcoh complete in 0m 19s
# Starting epoch number 110
# Loss for Training on Epoch 110 is 0.17160721123218536
# Epcoh complete in 0m 19s
# Starting epoch number 111
# Loss for Training on Epoch 111 is 0.16496022045612335
# Epcoh complete in 0m 19s
# Starting epoch number 112
# Loss for Training on Epoch 112 is 0.16334174573421478
# Epcoh complete in 0m 19s
# Starting epoch number 113
# Loss for Training on Epoch 113 is 0.1638175994157791
# Epcoh complete in 0m 19s
# Starting epoch number 114
# Loss for Training on Epoch 114 is 0.1641579419374466
# Epcoh complete in 0m 19s
# Starting epoch number 115
# Loss for Training on Epoch 115 is 0.1614162027835846
# Epcoh complete in 0m 18s
# Starting epoch number 116
# Loss for Training on Epoch 116 is 0.16184960305690765
# Epcoh complete in 0m 18s
# Starting epoch number 117
# Loss for Training on Epoch 117 is 0.1625545471906662
# Epcoh complete in 0m 19s
# Starting epoch number 118
# Loss for Training on Epoch 118 is 0.16831357777118683
# Epcoh complete in 0m 19s
# Starting epoch number 119
# Loss for Training on Epoch 119 is 0.16196845471858978
# Epcoh complete in 0m 19s
# Starting epoch number 120
# Loss for Training on Epoch 120 is 0.16488049924373627
# Epcoh complete in 0m 19s
# Starting epoch number 121
# Loss for Training on Epoch 121 is 0.16560052335262299
# Epcoh complete in 0m 19s
# Starting epoch number 122
# Loss for Training on Epoch 122 is 0.15642954409122467
# Epcoh complete in 0m 18s
# Starting epoch number 123
# Loss for Training on Epoch 123 is 0.15947669744491577
# Epcoh complete in 0m 19s
# Starting epoch number 124
# Loss for Training on Epoch 124 is 0.16313223540782928
# Epcoh complete in 0m 19s
# Starting epoch number 125
# Loss for Training on Epoch 125 is 0.15638013184070587
# Epcoh complete in 0m 19s
# Starting epoch number 126
# Loss for Training on Epoch 126 is 0.15665706992149353
# Epcoh complete in 0m 19s
# Starting epoch number 127
# Loss for Training on Epoch 127 is 0.15795934200286865
# Epcoh complete in 0m 19s
# Starting epoch number 128
# Loss for Training on Epoch 128 is 0.16230350732803345
# Epcoh complete in 0m 19s
# Starting epoch number 129
# Loss for Training on Epoch 129 is 0.1700972467660904
# Epcoh complete in 0m 19s
# Starting epoch number 130
# Loss for Training on Epoch 130 is 0.1590735763311386
# Epcoh complete in 0m 19s
# Starting epoch number 131
# Loss for Training on Epoch 131 is 0.1631380319595337
# Epcoh complete in 0m 19s
# Starting epoch number 132
# Loss for Training on Epoch 132 is 0.1566118448972702
# Epcoh complete in 0m 19s
# Starting epoch number 133
# Loss for Training on Epoch 133 is 0.15642546117305756
# Epcoh complete in 0m 18s
# Starting epoch number 134
# Loss for Training on Epoch 134 is 0.15697012841701508
# Epcoh complete in 0m 19s
# Starting epoch number 135
# Loss for Training on Epoch 135 is 0.15203963220119476
# Epcoh complete in 0m 19s
# Starting epoch number 136
# Loss for Training on Epoch 136 is 0.15301047265529633
# Epcoh complete in 0m 19s
# Starting epoch number 137
# Loss for Training on Epoch 137 is 0.15775534510612488
# Epcoh complete in 0m 19s
# Starting epoch number 138
# Loss for Training on Epoch 138 is 0.15625141561031342
# Epcoh complete in 0m 19s
# Starting epoch number 139
# Loss for Training on Epoch 139 is 0.15155981481075287
# Epcoh complete in 0m 19s
# Starting epoch number 140
# Loss for Training on Epoch 140 is 0.14896941184997559
# Epcoh complete in 0m 19s
# Starting epoch number 141
# Loss for Training on Epoch 141 is 0.14737218618392944
# Epcoh complete in 0m 19s
# Starting epoch number 142
# Loss for Training on Epoch 142 is 0.15481102466583252
# Epcoh complete in 0m 19s
# Starting epoch number 143
# Loss for Training on Epoch 143 is 0.16090920567512512
# Epcoh complete in 0m 19s
# Starting epoch number 144
# Loss for Training on Epoch 144 is 0.1543382704257965
# Epcoh complete in 0m 19s
# Starting epoch number 145
# Loss for Training on Epoch 145 is 0.15301384031772614
# Epcoh complete in 0m 19s
# Starting epoch number 146
# Loss for Training on Epoch 146 is 0.15754865109920502
# Epcoh complete in 0m 19s
# Starting epoch number 147
# Loss for Training on Epoch 147 is 0.15535187721252441
# Epcoh complete in 0m 19s
# Starting epoch number 148
# Loss for Training on Epoch 148 is 0.14752906560897827
# Epcoh complete in 0m 19s
# Starting epoch number 149
# Loss for Training on Epoch 149 is 0.14877572655677795
# Epcoh complete in 0m 19s
# Starting epoch number 150
# Loss for Training on Epoch 150 is 0.15081830322742462
# -------  Class: aeroplane        AP:   0.5933  -------
# -------  Class: bicycle          AP:   0.4362  -------
# -------  Class: bird             AP:   0.3603  -------
# -------  Class: boat             AP:   0.4453  -------
# -------  Class: bottle           AP:   0.2037  -------
# -------  Class: bus              AP:   0.3620  -------
# -------  Class: car              AP:   0.6165  -------
# -------  Class: cat              AP:   0.3763  -------
# -------  Class: chair            AP:   0.5133  -------
# -------  Class: cow              AP:   0.1900  -------
# -------  Class: diningtable      AP:   0.4503  -------
# -------  Class: dog              AP:   0.3006  -------
# -------  Class: horse            AP:   0.5606  -------
# -------  Class: motorbike        AP:   0.5692  -------
# -------  Class: person           AP:   0.8052  -------
# -------  Class: pottedplant      AP:   0.1940  -------
# -------  Class: sheep            AP:   0.1541  -------
# -------  Class: sofa             AP:   0.3156  -------
# -------  Class: train            AP:   0.6036  -------
# -------  Class: tvmonitor        AP:   0.3944  -------
# mAP: 0.4222
# Avg loss: 0.17155171297490596
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 150 is 0.4222222120284229
# Epcoh complete in 0m 55s

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.08, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=3e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)

plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.14370910823345184
# -------  Class: aeroplane        AP:   0.6076  -------
# -------  Class: bicycle          AP:   0.3789  -------
# -------  Class: bird             AP:   0.3260  -------
# -------  Class: boat             AP:   0.4269  -------
# -------  Class: bottle           AP:   0.1976  -------
# -------  Class: bus              AP:   0.4011  -------
# -------  Class: car              AP:   0.6621  -------
# -------  Class: cat              AP:   0.4097  -------
# -------  Class: chair            AP:   0.4906  -------
# -------  Class: cow              AP:   0.2282  -------
# -------  Class: diningtable      AP:   0.4012  -------
# -------  Class: dog              AP:   0.3042  -------
# -------  Class: horse            AP:   0.5694  -------
# -------  Class: motorbike        AP:   0.5955  -------
# -------  Class: person           AP:   0.8051  -------
# -------  Class: pottedplant      AP:   0.1987  -------
# -------  Class: sheep            AP:   0.1354  -------
# -------  Class: sofa             AP:   0.3637  -------
# -------  Class: train            AP:   0.6570  -------
# -------  Class: tvmonitor        AP:   0.3594  -------
# mAP: 0.4259
# Avg loss: 0.17266503684222698
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.42591517232620274
# Epcoh complete in 0m 55s
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.142471045255661
# Epcoh complete in 0m 19s
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.14625798165798187
# Epcoh complete in 0m 19s
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.14564047753810883
# Epcoh complete in 0m 19s
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.14463607966899872
# Epcoh complete in 0m 19s
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.1464465856552124
# Epcoh complete in 0m 19s
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.13865983486175537
# Epcoh complete in 0m 19s
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.13985766470432281
# Epcoh complete in 0m 19s
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.13673891127109528
# Epcoh complete in 0m 19s
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.136548712849617
# Epcoh complete in 0m 19s
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.13839499652385712
# Epcoh complete in 0m 19s
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.13676945865154266
# Epcoh complete in 0m 19s
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.13730154931545258
# Epcoh complete in 0m 19s
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.13846467435359955
# Epcoh complete in 0m 19s
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.14130137860774994
# Epcoh complete in 0m 19s
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.14148329198360443
# Epcoh complete in 0m 19s
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.13766878843307495
# Epcoh complete in 0m 19s
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.13409210741519928
# Epcoh complete in 0m 19s
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.13396574556827545
# Epcoh complete in 0m 19s
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.13559570908546448
# Epcoh complete in 0m 19s
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.13565707206726074
# Epcoh complete in 0m 19s
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.13638931512832642
# Epcoh complete in 0m 19s
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.1419253796339035
# Epcoh complete in 0m 19s
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.13757668435573578
# Epcoh complete in 0m 19s
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.13796472549438477
# Epcoh complete in 0m 19s
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.13395977020263672
# Epcoh complete in 0m 19s
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.13379226624965668
# Epcoh complete in 0m 19s
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.1332508772611618
# Epcoh complete in 0m 19s
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.13755205273628235
# Epcoh complete in 0m 19s
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.1303962767124176
# Epcoh complete in 0m 20s
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.13487353920936584
# Epcoh complete in 0m 20s
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.1324865072965622
# Epcoh complete in 0m 19s
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.12932731211185455
# Epcoh complete in 0m 18s
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.1325971931219101
# Epcoh complete in 0m 18s
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.1327962875366211
# Epcoh complete in 0m 19s
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.14276564121246338
# Epcoh complete in 0m 19s
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.13444827497005463
# Epcoh complete in 0m 19s
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.12952931225299835
# Epcoh complete in 0m 20s
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.12896095216274261
# Epcoh complete in 0m 19s
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.13005375862121582
# Epcoh complete in 0m 19s
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.12891703844070435
# Epcoh complete in 0m 19s
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.12333547323942184
# Epcoh complete in 0m 19s
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.12150242179632187
# Epcoh complete in 0m 19s
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.1235513910651207
# Epcoh complete in 0m 18s
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.12891094386577606
# Epcoh complete in 0m 19s
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.1247912049293518
# Epcoh complete in 0m 19s
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.12816773355007172
# Epcoh complete in 0m 19s
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.12317924946546555
# Epcoh complete in 0m 19s
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.12396253645420074
# Epcoh complete in 0m 19s
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.12655900418758392
# -------  Class: aeroplane        AP:   0.6490  -------
# -------  Class: bicycle          AP:   0.4763  -------
# -------  Class: bird             AP:   0.3985  -------
# -------  Class: boat             AP:   0.4593  -------
# -------  Class: bottle           AP:   0.2013  -------
# -------  Class: bus              AP:   0.3725  -------
# -------  Class: car              AP:   0.6784  -------
# -------  Class: cat              AP:   0.4330  -------
# -------  Class: chair            AP:   0.4865  -------
# -------  Class: cow              AP:   0.2209  -------
# -------  Class: diningtable      AP:   0.4021  -------
# -------  Class: dog              AP:   0.3187  -------
# -------  Class: horse            AP:   0.6225  -------
# -------  Class: motorbike        AP:   0.6153  -------
# -------  Class: person           AP:   0.8231  -------
# -------  Class: pottedplant      AP:   0.1933  -------
# -------  Class: sheep            AP:   0.1708  -------
# -------  Class: sofa             AP:   0.3791  -------
# -------  Class: train            AP:   0.6048  -------
# -------  Class: tvmonitor        AP:   0.3789  -------
# mAP: 0.4442
# Avg loss: 0.17766724713146687
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.4442151467107024
# Epcoh complete in 0m 54s
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.1259985715150833
# Epcoh complete in 0m 19s
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.12482374161481857
# Epcoh complete in 0m 20s
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.12440381199121475
# Epcoh complete in 0m 19s
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.12356702238321304
# Epcoh complete in 0m 19s
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.11895208805799484
# Epcoh complete in 0m 19s
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.11876201629638672
# Epcoh complete in 0m 18s
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.12155207246541977
# Epcoh complete in 0m 19s
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.12582562863826752
# Epcoh complete in 0m 19s
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.12256493419408798
# Epcoh complete in 0m 18s
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.1158483624458313
# Epcoh complete in 0m 19s
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.11984173208475113
# Epcoh complete in 0m 20s
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.12206830829381943
# Epcoh complete in 0m 19s
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.11764378845691681
# Epcoh complete in 0m 19s
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.1273912489414215
# Epcoh complete in 0m 19s
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.11504578590393066
# Epcoh complete in 0m 19s
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.11730408668518066
# Epcoh complete in 0m 19s
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.12058838456869125
# Epcoh complete in 0m 19s
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.12616652250289917
# Epcoh complete in 0m 20s
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.1215045228600502
# Epcoh complete in 0m 19s
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.11688318103551865
# Epcoh complete in 0m 19s
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.11552522331476212
# Epcoh complete in 0m 19s
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.12310697883367538
# Epcoh complete in 0m 19s
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.11945638805627823
# Epcoh complete in 0m 20s
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.11933993548154831
# Epcoh complete in 0m 19s
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.11900470405817032
# Epcoh complete in 0m 19s
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.11535531282424927
# Epcoh complete in 0m 19s
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.11456263065338135
# Epcoh complete in 0m 19s
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.1132202297449112
# Epcoh complete in 0m 19s
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.11473803967237473
# Epcoh complete in 0m 19s
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.1189102903008461
# Epcoh complete in 0m 20s
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.1177796721458435
# Epcoh complete in 0m 20s
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.11374720185995102
# Epcoh complete in 0m 19s
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.11009987443685532
# Epcoh complete in 0m 20s
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.11055823415517807
# Epcoh complete in 0m 20s
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.11382551491260529
# Epcoh complete in 0m 19s
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.11782419681549072
# Epcoh complete in 0m 19s
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.1079997792840004
# Epcoh complete in 0m 19s
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.10980726778507233
# Epcoh complete in 0m 19s
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.10996025055646896
# Epcoh complete in 0m 18s
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.10797297209501266
# Epcoh complete in 0m 19s
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.10703932493925095
# Epcoh complete in 0m 18s
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.11085336655378342
# Epcoh complete in 0m 20s
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.11359602212905884
# Epcoh complete in 0m 19s
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.11423783749341965
# Epcoh complete in 0m 19s
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.10948773473501205
# Epcoh complete in 0m 19s
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.10532074421644211
# Epcoh complete in 0m 19s
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.109136201441288
# Epcoh complete in 0m 19s
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.10759153217077255
# Epcoh complete in 0m 19s
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.10839595645666122
# Epcoh complete in 0m 18s
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.11168920248746872
# -------  Class: aeroplane        AP:   0.5833  -------
# -------  Class: bicycle          AP:   0.3967  -------
# -------  Class: bird             AP:   0.3853  -------
# -------  Class: boat             AP:   0.4337  -------
# -------  Class: bottle           AP:   0.2285  -------
# -------  Class: bus              AP:   0.3969  -------
# -------  Class: car              AP:   0.6306  -------
# -------  Class: cat              AP:   0.4484  -------
# -------  Class: chair            AP:   0.4878  -------
# -------  Class: cow              AP:   0.2544  -------
# -------  Class: diningtable      AP:   0.4049  -------
# -------  Class: dog              AP:   0.3097  -------
# -------  Class: horse            AP:   0.6347  -------
# -------  Class: motorbike        AP:   0.5978  -------
# -------  Class: person           AP:   0.8331  -------
# -------  Class: pottedplant      AP:   0.2410  -------
# -------  Class: sheep            AP:   0.1641  -------
# -------  Class: sofa             AP:   0.3506  -------
# -------  Class: train            AP:   0.7081  -------
# -------  Class: tvmonitor        AP:   0.3913  -------
# mAP: 0.4440
# Avg loss: 0.19179125390946866
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.4440406187717068
# Epcoh complete in 0m 55s
# Starting epoch number 101
# Loss for Training on Epoch 101 is 0.11516809463500977
# Epcoh complete in 0m 19s
# Starting epoch number 102
# Loss for Training on Epoch 102 is 0.10537197440862656
# Epcoh complete in 0m 19s
# Starting epoch number 103
# Loss for Training on Epoch 103 is 0.10460968315601349
# Epcoh complete in 0m 20s
# Starting epoch number 104
# Loss for Training on Epoch 104 is 0.11341724544763565
# Epcoh complete in 0m 19s
# Starting epoch number 105
# Loss for Training on Epoch 105 is 0.10662732273340225
# Epcoh complete in 0m 19s
# Starting epoch number 106
# Loss for Training on Epoch 106 is 0.10500550270080566
# Epcoh complete in 0m 20s
# Starting epoch number 107
# Loss for Training on Epoch 107 is 0.1053139716386795
# Epcoh complete in 0m 19s
# Starting epoch number 108
# Loss for Training on Epoch 108 is 0.10039224475622177
# Epcoh complete in 0m 19s
# Starting epoch number 109
# Loss for Training on Epoch 109 is 0.10779745876789093
# Epcoh complete in 0m 20s
# Starting epoch number 110
# Loss for Training on Epoch 110 is 0.10319072008132935
# Epcoh complete in 0m 19s
# Starting epoch number 111
# Loss for Training on Epoch 111 is 0.10550887882709503
# Epcoh complete in 0m 19s
# Starting epoch number 112
# Loss for Training on Epoch 112 is 0.10366127640008926
# Epcoh complete in 0m 19s
# Starting epoch number 113
# Loss for Training on Epoch 113 is 0.10140132904052734
# Epcoh complete in 0m 19s
# Starting epoch number 114
# Loss for Training on Epoch 114 is 0.10213343054056168
# Epcoh complete in 0m 19s
# Starting epoch number 115
# Loss for Training on Epoch 115 is 0.10341369360685349
# Epcoh complete in 0m 19s
# Starting epoch number 116
# Loss for Training on Epoch 116 is 0.10378038883209229
# Epcoh complete in 0m 19s
# Starting epoch number 117
# Loss for Training on Epoch 117 is 0.10087837278842926
# Epcoh complete in 0m 19s
# Starting epoch number 118
# Loss for Training on Epoch 118 is 0.10329563915729523
# Epcoh complete in 0m 19s
# Starting epoch number 119
# Loss for Training on Epoch 119 is 0.10639989376068115
# Epcoh complete in 0m 20s
# Starting epoch number 120
# Loss for Training on Epoch 120 is 0.10410880297422409
# Epcoh complete in 0m 19s
# Starting epoch number 121
# Loss for Training on Epoch 121 is 0.10101620107889175
# Epcoh complete in 0m 19s
# Starting epoch number 122
# Loss for Training on Epoch 122 is 0.09792742878198624
# Epcoh complete in 0m 19s
# Starting epoch number 123
# Loss for Training on Epoch 123 is 0.09551071375608444
# Epcoh complete in 0m 19s
# Starting epoch number 124
# Loss for Training on Epoch 124 is 0.10070157051086426
# Epcoh complete in 0m 19s
# Starting epoch number 125
# Loss for Training on Epoch 125 is 0.10087134689092636
# Epcoh complete in 0m 19s
# Starting epoch number 126
# Loss for Training on Epoch 126 is 0.09714339673519135
# Epcoh complete in 0m 19s
# Starting epoch number 127
# Loss for Training on Epoch 127 is 0.11379299312829971
# Epcoh complete in 0m 19s
# Starting epoch number 128
# Loss for Training on Epoch 128 is 0.10803098976612091
# Epcoh complete in 0m 20s
# Starting epoch number 129
# Loss for Training on Epoch 129 is 0.10435434430837631
# Epcoh complete in 0m 19s
# Starting epoch number 130
# Loss for Training on Epoch 130 is 0.09770002961158752
# Epcoh complete in 0m 20s
# Starting epoch number 131
# Loss for Training on Epoch 131 is 0.11070168018341064
# Epcoh complete in 0m 19s
# Starting epoch number 132
# Loss for Training on Epoch 132 is 0.10134690254926682
# Epcoh complete in 0m 19s
# Starting epoch number 133
# Loss for Training on Epoch 133 is 0.10328896343708038
# Epcoh complete in 0m 18s
# Starting epoch number 134
# Loss for Training on Epoch 134 is 0.10151475667953491
# Epcoh complete in 0m 19s
# Starting epoch number 135
# Loss for Training on Epoch 135 is 0.10177214443683624
# Epcoh complete in 0m 19s
# Starting epoch number 136
# Loss for Training on Epoch 136 is 0.09552138298749924
# Epcoh complete in 0m 19s
# Starting epoch number 137
# Loss for Training on Epoch 137 is 0.09767292439937592
# Epcoh complete in 0m 19s
# Starting epoch number 138
# Loss for Training on Epoch 138 is 0.09753469377756119
# Epcoh complete in 0m 19s
# Starting epoch number 139
# Loss for Training on Epoch 139 is 0.12156394869089127
# Epcoh complete in 0m 19s
# Starting epoch number 140
# Loss for Training on Epoch 140 is 0.10258074104785919
# Epcoh complete in 0m 18s
# Starting epoch number 141
# Loss for Training on Epoch 141 is 0.09854128956794739
# Epcoh complete in 0m 19s
# Starting epoch number 142
# Loss for Training on Epoch 142 is 0.10039707273244858
# Epcoh complete in 0m 19s
# Starting epoch number 143
# Loss for Training on Epoch 143 is 0.10087647289037704
# Epcoh complete in 0m 19s
# Starting epoch number 144
# Loss for Training on Epoch 144 is 0.09798216074705124
# Epcoh complete in 0m 19s
# Starting epoch number 145
# Loss for Training on Epoch 145 is 0.10498330742120743
# Epcoh complete in 0m 19s
# Starting epoch number 146
# Loss for Training on Epoch 146 is 0.09844391793012619
# Epcoh complete in 0m 19s
# Starting epoch number 147
# Loss for Training on Epoch 147 is 0.09328224509954453
# Epcoh complete in 0m 19s
# Starting epoch number 148
# Loss for Training on Epoch 148 is 0.09479407966136932
# Epcoh complete in 0m 19s
# Starting epoch number 149
# Loss for Training on Epoch 149 is 0.10190015286207199
# Epcoh complete in 0m 19s
# Starting epoch number 150
# Loss for Training on Epoch 150 is 0.10758036375045776
# -------  Class: aeroplane        AP:   0.6443  -------
# -------  Class: bicycle          AP:   0.4722  -------
# -------  Class: bird             AP:   0.4044  -------
# -------  Class: boat             AP:   0.4174  -------
# -------  Class: bottle           AP:   0.1991  -------
# -------  Class: bus              AP:   0.4064  -------
# -------  Class: car              AP:   0.6659  -------
# -------  Class: cat              AP:   0.4323  -------
# -------  Class: chair            AP:   0.4798  -------
# -------  Class: cow              AP:   0.2731  -------
# -------  Class: diningtable      AP:   0.4329  -------
# -------  Class: dog              AP:   0.3197  -------
# -------  Class: horse            AP:   0.6406  -------
# -------  Class: motorbike        AP:   0.5562  -------
# -------  Class: person           AP:   0.8175  -------
# -------  Class: pottedplant      AP:   0.2267  -------
# -------  Class: sheep            AP:   0.1713  -------
# -------  Class: sofa             AP:   0.3207  -------
# -------  Class: train            AP:   0.6770  -------
# -------  Class: tvmonitor        AP:   0.4392  -------
# mAP: 0.4498
# Avg loss: 0.19226236678659916
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 150 is 0.4498391341265484
# Epcoh complete in 0m 56s

# %%
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.07, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=3e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)

plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.0948217585682869
# -------  Class: aeroplane        AP:   0.6581  -------
# -------  Class: bicycle          AP:   0.5271  -------
# -------  Class: bird             AP:   0.4394  -------
# -------  Class: boat             AP:   0.4711  -------
# -------  Class: bottle           AP:   0.1707  -------
# -------  Class: bus              AP:   0.4693  -------
# -------  Class: car              AP:   0.6842  -------
# -------  Class: cat              AP:   0.4138  -------
# -------  Class: chair            AP:   0.4925  -------
# -------  Class: cow              AP:   0.2319  -------
# -------  Class: diningtable      AP:   0.3626  -------
# -------  Class: dog              AP:   0.3408  -------
# -------  Class: horse            AP:   0.6238  -------
# -------  Class: motorbike        AP:   0.6144  -------
# -------  Class: person           AP:   0.8382  -------
# -------  Class: pottedplant      AP:   0.2066  -------
# -------  Class: sheep            AP:   0.1402  -------
# -------  Class: sofa             AP:   0.3576  -------
# -------  Class: train            AP:   0.6824  -------
# -------  Class: tvmonitor        AP:   0.4073  -------
# mAP: 0.4566
# Avg loss: 0.1913491789251566
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.45660498133447514
# Epcoh complete in 0m 56s
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.09288441389799118
# Epcoh complete in 0m 19s
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.09741221368312836
# Epcoh complete in 0m 19s
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.09444638341665268
# Epcoh complete in 0m 20s
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.09579789638519287
# Epcoh complete in 0m 20s
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.09345799684524536
# Epcoh complete in 0m 20s
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.09346505254507065
# Epcoh complete in 0m 19s
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.08619381487369537
# Epcoh complete in 0m 19s
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.09459813684225082
# Epcoh complete in 0m 20s
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.09388517588376999
# Epcoh complete in 0m 20s
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.09531815350055695
# Epcoh complete in 0m 20s
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.08706655353307724
# Epcoh complete in 0m 19s
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.08820780366659164
# Epcoh complete in 0m 20s
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.08452849835157394
# Epcoh complete in 0m 20s
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.09049924463033676
# Epcoh complete in 0m 19s
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.09313187748193741
# Epcoh complete in 0m 19s
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.08561120927333832
# Epcoh complete in 0m 19s
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.08905892819166183
# Epcoh complete in 0m 20s
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.08555196970701218
# Epcoh complete in 0m 20s
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.08484231680631638
# Epcoh complete in 0m 19s
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.08406169712543488
# Epcoh complete in 0m 19s
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.09045534580945969
# Epcoh complete in 0m 20s
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.09298812597990036
# Epcoh complete in 0m 20s
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.09118824452161789
# Epcoh complete in 0m 19s
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.0895862802863121
# Epcoh complete in 0m 19s
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.08148634433746338
# Epcoh complete in 0m 20s
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.08805733174085617
# Epcoh complete in 0m 18s
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.08336132019758224
# Epcoh complete in 0m 20s
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.08195453137159348
# Epcoh complete in 0m 19s
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.09175174683332443
# Epcoh complete in 0m 20s
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.08429797738790512
# Epcoh complete in 0m 20s
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.0846165120601654
# Epcoh complete in 0m 19s
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.08185147494077682
# Epcoh complete in 0m 20s
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.08166082948446274
# Epcoh complete in 0m 20s
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.0818474218249321
# Epcoh complete in 0m 18s
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.08225899189710617
# Epcoh complete in 0m 20s
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.08136294782161713
# Epcoh complete in 0m 20s
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.08093204349279404
# Epcoh complete in 0m 20s
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.09557949751615524
# Epcoh complete in 0m 20s
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.08537333458662033
# Epcoh complete in 0m 18s
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.08376498520374298
# Epcoh complete in 0m 19s
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.08000829070806503
# Epcoh complete in 0m 19s
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.08281000703573227
# Epcoh complete in 0m 18s
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.08704037964344025
# Epcoh complete in 0m 19s
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.09023809432983398
# Epcoh complete in 0m 20s
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.08592625707387924
# Epcoh complete in 0m 20s
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.08279847353696823
# Epcoh complete in 0m 19s
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.08009719848632812
# Epcoh complete in 0m 20s
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.09117889404296875
# Epcoh complete in 0m 20s
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.08233000338077545
# -------  Class: aeroplane        AP:   0.6261  -------
# -------  Class: bicycle          AP:   0.4689  -------
# -------  Class: bird             AP:   0.4101  -------
# -------  Class: boat             AP:   0.4494  -------
# -------  Class: bottle           AP:   0.1310  -------
# -------  Class: bus              AP:   0.4224  -------
# -------  Class: car              AP:   0.6847  -------
# -------  Class: cat              AP:   0.4099  -------
# -------  Class: chair            AP:   0.4692  -------
# -------  Class: cow              AP:   0.2733  -------
# -------  Class: diningtable      AP:   0.3663  -------
# -------  Class: dog              AP:   0.3211  -------
# -------  Class: horse            AP:   0.6278  -------
# -------  Class: motorbike        AP:   0.5580  -------
# -------  Class: person           AP:   0.8170  -------
# -------  Class: pottedplant      AP:   0.2344  -------
# -------  Class: sheep            AP:   0.1394  -------
# -------  Class: sofa             AP:   0.3277  -------
# -------  Class: train            AP:   0.6871  -------
# -------  Class: tvmonitor        AP:   0.3844  -------
# mAP: 0.4404
# Avg loss: 0.22120604924857618
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.440413160766743
# Epcoh complete in 0m 56s
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.079062819480896
# Epcoh complete in 0m 20s
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.08591917157173157
# Epcoh complete in 0m 20s
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.07798262685537338
# Epcoh complete in 0m 20s
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.07876179367303848
# Epcoh complete in 0m 20s
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.07602179795503616
# Epcoh complete in 0m 19s
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.0784517452120781
# Epcoh complete in 0m 20s
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.07423045486211777
# Epcoh complete in 0m 19s
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.0763201117515564
# Epcoh complete in 0m 20s
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.08669038116931915
# Epcoh complete in 0m 20s
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.07821301370859146
# Epcoh complete in 0m 20s
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.07470257580280304
# Epcoh complete in 0m 19s
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.07765408605337143
# Epcoh complete in 0m 19s
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.08319208770990372
# Epcoh complete in 0m 20s
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.07415717840194702
# Epcoh complete in 0m 20s
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.07546284794807434
# Epcoh complete in 0m 19s
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.08248071372509003
# Epcoh complete in 0m 20s
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.07504376769065857
# Epcoh complete in 0m 20s
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.07605995982885361
# Epcoh complete in 0m 20s
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.07372768968343735
# Epcoh complete in 0m 20s
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.07825016230344772
# Epcoh complete in 0m 19s
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.0720842257142067
# Epcoh complete in 0m 20s
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.08005144447088242
# Epcoh complete in 0m 20s
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.10415704548358917
# Epcoh complete in 0m 20s
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.08639006316661835
# Epcoh complete in 0m 20s
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.07886357605457306
# Epcoh complete in 0m 20s
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.08040989190340042
# Epcoh complete in 0m 20s
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.0747796818614006
# Epcoh complete in 0m 20s
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.07713136821985245
# Epcoh complete in 0m 20s
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.07672949135303497
# Epcoh complete in 0m 20s
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.0803302675485611
# Epcoh complete in 0m 21s
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.07730349153280258
# Epcoh complete in 0m 20s
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.07273099571466446
# Epcoh complete in 0m 19s
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.07180549949407578
# Epcoh complete in 0m 20s
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.07277306169271469
# Epcoh complete in 0m 19s
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.07716371864080429
# Epcoh complete in 0m 19s
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.07397132366895676
# Epcoh complete in 0m 20s
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.07130032032728195
# Epcoh complete in 0m 19s
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.07104916870594025
# Epcoh complete in 0m 20s
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.07160322368144989
# Epcoh complete in 0m 20s
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.06933098286390305
# Epcoh complete in 0m 20s
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.07092582434415817
# Epcoh complete in 0m 18s
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.08024110645055771
# Epcoh complete in 0m 20s
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.07025700062513351
# Epcoh complete in 0m 20s
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.06789696216583252
# Epcoh complete in 0m 20s
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.06336294859647751
# Epcoh complete in 0m 20s
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.06932135671377182
# Epcoh complete in 0m 19s
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.07587641477584839
# Epcoh complete in 0m 20s
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.07329188287258148
# Epcoh complete in 0m 19s
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.07346881926059723
# Epcoh complete in 0m 20s
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.07999920099973679
# -------  Class: aeroplane        AP:   0.6545  -------
# -------  Class: bicycle          AP:   0.4904  -------
# -------  Class: bird             AP:   0.4202  -------
# -------  Class: boat             AP:   0.4564  -------
# -------  Class: bottle           AP:   0.1616  -------
# -------  Class: bus              AP:   0.4239  -------
# -------  Class: car              AP:   0.6836  -------
# -------  Class: cat              AP:   0.4317  -------
# -------  Class: chair            AP:   0.4736  -------
# -------  Class: cow              AP:   0.2342  -------
# -------  Class: diningtable      AP:   0.3841  -------
# -------  Class: dog              AP:   0.2928  -------
# -------  Class: horse            AP:   0.5989  -------
# -------  Class: motorbike        AP:   0.5708  -------
# -------  Class: person           AP:   0.8142  -------
# -------  Class: pottedplant      AP:   0.1992  -------
# -------  Class: sheep            AP:   0.1866  -------
# -------  Class: sofa             AP:   0.3291  -------
# -------  Class: train            AP:   0.6592  -------
# -------  Class: tvmonitor        AP:   0.3909  -------
# mAP: 0.4428
# Avg loss: 0.22401546500623226
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.4427858692314999
# Epcoh complete in 0m 56s
# Starting epoch number 101
# Loss for Training on Epoch 101 is 0.06906281411647797
# Epcoh complete in 0m 20s
# Starting epoch number 102
# Loss for Training on Epoch 102 is 0.06929846107959747
# Epcoh complete in 0m 20s
# Starting epoch number 103
# Loss for Training on Epoch 103 is 0.06817102432250977
# Epcoh complete in 0m 18s
# Starting epoch number 104
# Loss for Training on Epoch 104 is 0.06919576972723007
# Epcoh complete in 0m 20s
# Starting epoch number 105
# Loss for Training on Epoch 105 is 0.06870429962873459
# Epcoh complete in 0m 20s
# Starting epoch number 106
# Loss for Training on Epoch 106 is 0.06460140645503998
# Epcoh complete in 0m 20s
# Starting epoch number 107
# Loss for Training on Epoch 107 is 0.07408057153224945
# Epcoh complete in 0m 20s
# Starting epoch number 108
# Loss for Training on Epoch 108 is 0.07132746279239655
# Epcoh complete in 0m 20s
# Starting epoch number 109
# Loss for Training on Epoch 109 is 0.06471750885248184
# Epcoh complete in 0m 20s
# Starting epoch number 110
# Loss for Training on Epoch 110 is 0.07493168115615845
# Epcoh complete in 0m 20s
# Starting epoch number 111
# Loss for Training on Epoch 111 is 0.06989605724811554
# Epcoh complete in 0m 20s
# Starting epoch number 112
# Loss for Training on Epoch 112 is 0.06817623227834702
# Epcoh complete in 0m 20s
# Starting epoch number 113
# Loss for Training on Epoch 113 is 0.06477435678243637
# Epcoh complete in 0m 18s
# Starting epoch number 114
# Loss for Training on Epoch 114 is 0.063540019094944
# Epcoh complete in 0m 20s
# Starting epoch number 115
# Loss for Training on Epoch 115 is 0.06389535218477249
# Epcoh complete in 0m 20s
# Starting epoch number 116
# Loss for Training on Epoch 116 is 0.061839330941438675
# Epcoh complete in 0m 20s
# Starting epoch number 117
# Loss for Training on Epoch 117 is 0.06269974261522293
# Epcoh complete in 0m 20s
# Starting epoch number 118
# Loss for Training on Epoch 118 is 0.06573221832513809
# Epcoh complete in 0m 20s
# Starting epoch number 119
# Loss for Training on Epoch 119 is 0.06877738982439041
# Epcoh complete in 0m 19s
# Starting epoch number 120
# Loss for Training on Epoch 120 is 0.06715767830610275
# Epcoh complete in 0m 19s
# Starting epoch number 121
# Loss for Training on Epoch 121 is 0.0668780729174614
# Epcoh complete in 0m 18s
# Starting epoch number 122
# Loss for Training on Epoch 122 is 0.07127823680639267
# Epcoh complete in 0m 19s
# Starting epoch number 123
# Loss for Training on Epoch 123 is 0.0702996701002121
# Epcoh complete in 0m 20s
# Starting epoch number 124
# Loss for Training on Epoch 124 is 0.0619327537715435
# Epcoh complete in 0m 20s
# Starting epoch number 125
# Loss for Training on Epoch 125 is 0.0653851181268692
# Epcoh complete in 0m 20s
# Starting epoch number 126
# Loss for Training on Epoch 126 is 0.0701090469956398
# Epcoh complete in 0m 20s
# Starting epoch number 127
# Loss for Training on Epoch 127 is 0.06512457132339478
# Epcoh complete in 0m 19s
# Starting epoch number 128
# Loss for Training on Epoch 128 is 0.06277509033679962
# Epcoh complete in 0m 20s
# Starting epoch number 129
# Loss for Training on Epoch 129 is 0.06328486651182175
# Epcoh complete in 0m 18s
# Starting epoch number 130
# Loss for Training on Epoch 130 is 0.05991993099451065
# Epcoh complete in 0m 20s
# Starting epoch number 131
# Loss for Training on Epoch 131 is 0.06557431817054749
# Epcoh complete in 0m 20s
# Starting epoch number 132
# Loss for Training on Epoch 132 is 0.05826893076300621
# Epcoh complete in 0m 20s
# Starting epoch number 133
# Loss for Training on Epoch 133 is 0.0629226565361023
# Epcoh complete in 0m 20s
# Starting epoch number 134
# Loss for Training on Epoch 134 is 0.06109802797436714
# Epcoh complete in 0m 18s
# Starting epoch number 135
# Loss for Training on Epoch 135 is 0.061070289462804794
# Epcoh complete in 0m 20s
# Starting epoch number 136
# Loss for Training on Epoch 136 is 0.05905168130993843
# Epcoh complete in 0m 19s
# Starting epoch number 137
# Loss for Training on Epoch 137 is 0.059535395354032516
# Epcoh complete in 0m 20s
# Starting epoch number 138
# Loss for Training on Epoch 138 is 0.06303868442773819
# Epcoh complete in 0m 20s
# Starting epoch number 139
# Loss for Training on Epoch 139 is 0.06128089502453804
# Epcoh complete in 0m 20s
# Starting epoch number 140
# Loss for Training on Epoch 140 is 0.060890328139066696
# Epcoh complete in 0m 20s
# Starting epoch number 141
# Loss for Training on Epoch 141 is 0.058551765978336334
# Epcoh complete in 0m 19s
# Starting epoch number 142
# Loss for Training on Epoch 142 is 0.06308645009994507
# Epcoh complete in 0m 20s
# Starting epoch number 143
# Loss for Training on Epoch 143 is 0.06167704984545708
# Epcoh complete in 0m 19s
# Starting epoch number 144
# Loss for Training on Epoch 144 is 0.06431227922439575
# Epcoh complete in 0m 20s
# Starting epoch number 145
# Loss for Training on Epoch 145 is 0.06366871297359467
# Epcoh complete in 0m 20s
# Starting epoch number 146
# Loss for Training on Epoch 146 is 0.06333216279745102
# Epcoh complete in 0m 20s
# Starting epoch number 147
# Loss for Training on Epoch 147 is 0.06454291194677353
# Epcoh complete in 0m 20s
# Starting epoch number 148
# Loss for Training on Epoch 148 is 0.05823380872607231
# Epcoh complete in 0m 20s
# Starting epoch number 149
# Loss for Training on Epoch 149 is 0.06104646250605583
# Epcoh complete in 0m 18s
# Starting epoch number 150
# Loss for Training on Epoch 150 is 0.06665300577878952
# -------  Class: aeroplane        AP:   0.6534  -------
# -------  Class: bicycle          AP:   0.4561  -------
# -------  Class: bird             AP:   0.3888  -------
# -------  Class: boat             AP:   0.4393  -------
# -------  Class: bottle           AP:   0.1420  -------
# -------  Class: bus              AP:   0.3416  -------
# -------  Class: car              AP:   0.6776  -------
# -------  Class: cat              AP:   0.4253  -------
# -------  Class: chair            AP:   0.4854  -------
# -------  Class: cow              AP:   0.2122  -------
# -------  Class: diningtable      AP:   0.3940  -------
# -------  Class: dog              AP:   0.3050  -------
# -------  Class: horse            AP:   0.6144  -------
# -------  Class: motorbike        AP:   0.4945  -------
# -------  Class: person           AP:   0.8403  -------
# -------  Class: pottedplant      AP:   0.1900  -------
# -------  Class: sheep            AP:   0.1825  -------
# -------  Class: sofa             AP:   0.3108  -------
# -------  Class: train            AP:   0.6803  -------
# -------  Class: tvmonitor        AP:   0.3392  -------
# mAP: 0.4286
# Avg loss: 0.2399005688726902
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 150 is 0.42862251602714296
# Epcoh complete in 0m 57s

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.6423  -------
# -------  Class: bicycle          AP:   0.4668  -------
# -------  Class: bird             AP:   0.3820  -------
# -------  Class: boat             AP:   0.4312  -------
# -------  Class: bottle           AP:   0.1404  -------
# -------  Class: bus              AP:   0.3542  -------
# -------  Class: car              AP:   0.7257  -------
# -------  Class: cat              AP:   0.4531  -------
# -------  Class: chair            AP:   0.4645  -------
# -------  Class: cow              AP:   0.2619  -------
# -------  Class: diningtable      AP:   0.3603  -------
# -------  Class: dog              AP:   0.4062  -------
# -------  Class: horse            AP:   0.6929  -------
# -------  Class: motorbike        AP:   0.4969  -------
# -------  Class: person           AP:   0.8516  -------
# -------  Class: pottedplant      AP:   0.2215  -------
# -------  Class: sheep            AP:   0.3181  -------
# -------  Class: sofa             AP:   0.3419  -------
# -------  Class: train            AP:   0.6545  -------
# -------  Class: tvmonitor        AP:   0.3890  -------
# mAP: 0.4527
# Avg loss: 0.227773395104286
# 0.45274712925603644

# %%
# torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
# output_submission_csv('my_solution.csv', test_aps)
