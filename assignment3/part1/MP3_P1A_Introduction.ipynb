# %% [markdown]
# # Assignment 3 Part 1A Introduction: Multi-label Image Classification

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir("gdrive/My Drive/assignment3_part1")
# Out:
# Mounted at /content/gdrive

# %%
# !sh download_data.sh

import shutil 
shutil.copyfile("VOCtrainval_06-Nov-2007.tar", "/content/VOCtrainval_06-Nov-2007.tar")
# !tar -xf "/content/VOCtrainval_06-Nov-2007.tar" -C "/content/" 
shutil.move("/content/VOCdevkit/", "/content/VOCdevkit_2007")

shutil.copyfile("VOCtest_06-Nov-2007.tar", "/content/VOCtest_06-Nov-2007.tar")
# !tar -xf "/content/VOCtest_06-Nov-2007.tar" -C "/content/" 
shutil.move("/content/VOCdevkit/VOC2007", "/content/VOCdevkit_2007/VOC2007test")
# Out:
# --2021-03-18 15:39:51--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar.3’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  15.1MB/s    in 30s
#
# 2021-03-18 15:40:22 (14.6 MB/s) - ‘VOCtrainval_06-Nov-2007.tar.3’ saved [460032000/460032000]
#
# --2021-03-18 15:42:29--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar.3’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  15.0MB/s    in 29s
#
# 2021-03-18 15:42:59 (14.7 MB/s) - ‘VOCtest_06-Nov-2007.tar.3’ saved [451020800/451020800]
# '/content/VOCdevkit_2007/VOC2007test'

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Multi-label Classification
# In this assignment, you train a classifier to do multi-label classificaton on the PASCAL VOC 2007 dataset. The dataset has 20 different class which can appear in any given image. Your classifier will predict whether each class appears in an image. This task is slightly different from exclusive multiclass classification like the ImageNet competition where only a single most appropriate class is predicted for an image.
#
# ## Part 1A
# You will use this notebook to warm up with pytorch and the code+dataset that we will use for assignment3.
#
# ### What to do
# In part 1A, You are asked to run below experiments. You don't need to change hyperparameters for this Part 1A's experiments. (the following code provides everything that you will need.)
# 1. to train a simple network (defined in ```classifiers.py```)
# 2. to train the AlexNet (PyTorch built-in)
#     - from scratch
#     - finetuning AlexNet pretrained on ImageNet
#
#
#
# ### What to submit
# We ask you to run the following code and report the results in your homework submission. You may want to leverage this part 1A get yourself familiar with PyTorch.
#
# You will the need the numbers and plots this notebook outputs for reports, but you are not required to submit this notebook as a printed pdf.

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# ### Loading Training Data

# %% [markdown]
# In the following cell we will load the training data and also apply some transforms to the data.

# %%
# Transforms applied to the training data
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize
        ])

# %%
ds_train = VocDataset('VOCdevkit_2007/VOC2007/','train',train_transform)
# Out:
# /content/gdrive/My Drive/assignment3_part1/voc_dataloader.py:137: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(box_indices),

# %% [markdown]
# ### Loading Validation Data

# %% [markdown]
# We will load the test data for the PASCAL VOC 2007 dataset. Do __NOT__ add data augmentation transforms to validation data.

# %%
# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

# %%
ds_val = VocDataset('VOCdevkit_2007/VOC2007/','val',test_transform)
# Out:
# /content/gdrive/My Drive/assignment3_part1/voc_dataloader.py:137: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(box_indices),

# %% [markdown]
# ### Visualizing the Data
#
# PASCAL VOC has bounding box annotations in addition to class labels. Use the following code to visualize some random examples and corresponding annotations from the train set.

# %%
for i in range(5):
    idx = np.random.randint(0, len(ds_train.names)+1)
    _imgpath = os.path.join('VOCdevkit_2007/VOC2007/', 'JPEGImages', ds_train.names[idx]+'.jpg')
    img = Image.open(_imgpath).convert('RGB')
    draw = ImageDraw.Draw(img)
    for j in range(len(ds_train.box_indices[idx])):
        obj = ds_train.box_indices[idx][j]
        draw.rectangle(list(obj), outline=(255,0,0))
        draw.text(list(obj[0:2]), ds_train.classes[ds_train.label_order[idx][j]], fill=(0,255,0))
    plt.figure(figsize = (10,10))
    plt.imshow(np.array(img))

# %% [markdown]
# # Classification

# %%
# declare what device to use: gpu/cpu
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
# plot functions
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Training the network
#
# The simple network you are given as is will allow you to reach around 0.15-0.2 mAP. In this project, you will find ways to design a better network. Save plots and final test mAP scores as you will be adding these to the writeup.

# %%
import time 

def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        since = time.time()
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
        time_elapsed = time.time() - since
        print('Epcoh complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))

    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %%
classifier = SimpleClassifier().to(device)
# You can can use this function to reload a network you have already saved previously
# classifier.load_state_dict(torch.load('voc_classifier.pth'))

# %%
criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
# Training the Classifier
num_epochs = 20
test_frequency = 5

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.5585197806358337
# -------  Class: aeroplane        AP:   0.1662  -------
# -------  Class: bicycle          AP:   0.0518  -------
# -------  Class: bird             AP:   0.1040  -------
# -------  Class: boat             AP:   0.1072  -------
# -------  Class: bottle           AP:   0.0393  -------
# -------  Class: bus              AP:   0.0320  -------
# -------  Class: car              AP:   0.1151  -------
# -------  Class: cat              AP:   0.0821  -------
# -------  Class: chair            AP:   0.1115  -------
# -------  Class: cow              AP:   0.0320  -------
# -------  Class: diningtable      AP:   0.0490  -------
# -------  Class: dog              AP:   0.1106  -------
# -------  Class: horse            AP:   0.0513  -------
# -------  Class: motorbike        AP:   0.0430  -------
# -------  Class: person           AP:   0.4567  -------
# -------  Class: pottedplant      AP:   0.0438  -------
# -------  Class: sheep            AP:   0.0258  -------
# -------  Class: sofa             AP:   0.0837  -------
# -------  Class: train            AP:   0.0377  -------
# -------  Class: tvmonitor        AP:   0.0490  -------
# mAP: 0.0896
# Avg loss: 0.2706175183548647
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08958773155069663
# Epcoh complete in 18m 24s
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2498071789741516
# Epcoh complete in 0m 18s
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.2435847520828247
# Epcoh complete in 0m 20s
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.24219445884227753
# Epcoh complete in 0m 18s
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.24145542085170746
# -------  Class: aeroplane        AP:   0.0914  -------
# -------  Class: bicycle          AP:   0.0444  -------
# -------  Class: bird             AP:   0.1040  -------
# -------  Class: boat             AP:   0.0709  -------
# -------  Class: bottle           AP:   0.0448  -------
# -------  Class: bus              AP:   0.0281  -------
# -------  Class: car              AP:   0.1174  -------
# -------  Class: cat              AP:   0.1045  -------
# -------  Class: chair            AP:   0.1305  -------
# -------  Class: cow              AP:   0.0307  -------
# -------  Class: diningtable      AP:   0.0579  -------
# -------  Class: dog              AP:   0.1290  -------
# -------  Class: horse            AP:   0.0491  -------
# -------  Class: motorbike        AP:   0.0401  -------
# -------  Class: person           AP:   0.3571  -------
# -------  Class: pottedplant      AP:   0.0459  -------
# -------  Class: sheep            AP:   0.0266  -------
# -------  Class: sofa             AP:   0.1100  -------
# -------  Class: train            AP:   0.0355  -------
# -------  Class: tvmonitor        AP:   0.0547  -------
# mAP: 0.0837
# Avg loss: 0.23684065394541798
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.08365055277218317
# Epcoh complete in 0m 57s
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.24044831097126007
# Epcoh complete in 0m 19s
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.24278497695922852
# Epcoh complete in 0m 19s
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.2408081740140915
# Epcoh complete in 0m 18s
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.24324922263622284
# Epcoh complete in 0m 18s
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.23743869364261627
# -------  Class: aeroplane        AP:   0.0927  -------
# -------  Class: bicycle          AP:   0.0448  -------
# -------  Class: bird             AP:   0.1052  -------
# -------  Class: boat             AP:   0.0656  -------
# -------  Class: bottle           AP:   0.0451  -------
# -------  Class: bus              AP:   0.0287  -------
# -------  Class: car              AP:   0.1405  -------
# -------  Class: cat              AP:   0.1062  -------
# -------  Class: chair            AP:   0.1383  -------
# -------  Class: cow              AP:   0.0322  -------
# -------  Class: diningtable      AP:   0.0606  -------
# -------  Class: dog              AP:   0.1317  -------
# -------  Class: horse            AP:   0.0509  -------
# -------  Class: motorbike        AP:   0.0395  -------
# -------  Class: person           AP:   0.3975  -------
# -------  Class: pottedplant      AP:   0.0469  -------
# -------  Class: sheep            AP:   0.0301  -------
# -------  Class: sofa             AP:   0.1134  -------
# -------  Class: train            AP:   0.0372  -------
# -------  Class: tvmonitor        AP:   0.0583  -------
# mAP: 0.0883
# Avg loss: 0.23500006514437058
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.08827139631854354
# Epcoh complete in 0m 57s
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.2372678518295288
# Epcoh complete in 0m 18s
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.2368944138288498
# Epcoh complete in 0m 19s
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.23569799959659576
# Epcoh complete in 0m 18s
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.23221200704574585
# Epcoh complete in 0m 18s
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.23072533309459686
# -------  Class: aeroplane        AP:   0.2405  -------
# -------  Class: bicycle          AP:   0.0530  -------
# -------  Class: bird             AP:   0.1179  -------
# -------  Class: boat             AP:   0.1140  -------
# -------  Class: bottle           AP:   0.0575  -------
# -------  Class: bus              AP:   0.0423  -------
# -------  Class: car              AP:   0.1679  -------
# -------  Class: cat              AP:   0.1000  -------
# -------  Class: chair            AP:   0.1662  -------
# -------  Class: cow              AP:   0.0357  -------
# -------  Class: diningtable      AP:   0.0868  -------
# -------  Class: dog              AP:   0.1207  -------
# -------  Class: horse            AP:   0.0557  -------
# -------  Class: motorbike        AP:   0.0406  -------
# -------  Class: person           AP:   0.4799  -------
# -------  Class: pottedplant      AP:   0.0486  -------
# -------  Class: sheep            AP:   0.0327  -------
# -------  Class: sofa             AP:   0.1390  -------
# -------  Class: train            AP:   0.0655  -------
# -------  Class: tvmonitor        AP:   0.0629  -------
# mAP: 0.1114
# Avg loss: 0.2305210466478385
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.11137182083874382
# Epcoh complete in 0m 56s
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.22961905598640442
# Epcoh complete in 0m 18s
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.22998987138271332
# Epcoh complete in 0m 19s
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.2275848537683487
# Epcoh complete in 0m 18s
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.22835275530815125
# Epcoh complete in 0m 18s
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.22586625814437866
# -------  Class: aeroplane        AP:   0.3333  -------
# -------  Class: bicycle          AP:   0.0615  -------
# -------  Class: bird             AP:   0.1110  -------
# -------  Class: boat             AP:   0.2225  -------
# -------  Class: bottle           AP:   0.0747  -------
# -------  Class: bus              AP:   0.0706  -------
# -------  Class: car              AP:   0.1982  -------
# -------  Class: cat              AP:   0.1269  -------
# -------  Class: chair            AP:   0.1828  -------
# -------  Class: cow              AP:   0.0422  -------
# -------  Class: diningtable      AP:   0.1218  -------
# -------  Class: dog              AP:   0.1394  -------
# -------  Class: horse            AP:   0.0710  -------
# -------  Class: motorbike        AP:   0.0450  -------
# -------  Class: person           AP:   0.4825  -------
# -------  Class: pottedplant      AP:   0.0648  -------
# -------  Class: sheep            AP:   0.0449  -------
# -------  Class: sofa             AP:   0.1505  -------
# -------  Class: train            AP:   0.1099  -------
# -------  Class: tvmonitor        AP:   0.0671  -------
# mAP: 0.1360
# Avg loss: 0.22553981080943464
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.1360335538229303
# Epcoh complete in 0m 56s

# %%
# Compare train and validation metrics
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
# Save the clssifier network
# Suggestion: you can save checkpoints of your network during training and reload them later
torch.save(classifier.state_dict(), './voc_simple_classifier.pth')

# %% [markdown]
# # Evaluate on test set

# %%
ds_test = VocDataset('VOCdevkit_2007/VOC2007test/','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
# Out:
# /content/gdrive/My Drive/assignment3_part1/voc_dataloader.py:137: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(box_indices),
# -------  Class: aeroplane        AP:   0.2804  -------
# -------  Class: bicycle          AP:   0.0587  -------
# -------  Class: bird             AP:   0.1075  -------
# -------  Class: boat             AP:   0.1957  -------
# -------  Class: bottle           AP:   0.0666  -------
# -------  Class: bus              AP:   0.0559  -------
# -------  Class: car              AP:   0.2156  -------
# -------  Class: cat              AP:   0.1278  -------
# -------  Class: chair            AP:   0.1707  -------
# -------  Class: cow              AP:   0.0519  -------
# -------  Class: diningtable      AP:   0.0818  -------
# -------  Class: dog              AP:   0.1490  -------
# -------  Class: horse            AP:   0.0698  -------
# -------  Class: motorbike        AP:   0.0452  -------
# -------  Class: person           AP:   0.4918  -------
# -------  Class: pottedplant      AP:   0.0615  -------
# -------  Class: sheep            AP:   0.0851  -------
# -------  Class: sofa             AP:   0.1477  -------
# -------  Class: train            AP:   0.1301  -------
# -------  Class: tvmonitor        AP:   0.0667  -------
# mAP: 0.1330
# Avg loss: 0.22178271189332008

# %%
output_submission_csv('my_solution.csv', test_aps)

# %% [markdown]
# # AlexNet Baselines (From Scratch)

# %% [markdown]
# AlexNet was one of the earliest deep learning models to have success in classification. In this section we will be running classification with AlexNet as a baseline. Furthermore, we will run an ImageNet-pretrained AlexNet to observe the impact of well-trained features. Save plots and final test mAP scores as you will be adding these to the writeup.

# %% [markdown]
# ## Running AlexNet
#
# In this section, we train AlexNet from scratch using the same hyperparameters as our previous experiment.

# %%
num_epochs = 20
test_frequency = 5

# Change classifier to AlexNet
classifier = torchvision.models.alexnet(pretrained=False)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)

criterion = nn.MultiLabelSoftMarginLoss()

# optimizer = torch.optim.SGD(classifier.parameters(), lr=1e-4, momentum=0.9)
optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.2836384177207947
# -------  Class: aeroplane        AP:   0.1100  -------
# -------  Class: bicycle          AP:   0.0437  -------
# -------  Class: bird             AP:   0.1087  -------
# -------  Class: boat             AP:   0.1003  -------
# -------  Class: bottle           AP:   0.0418  -------
# -------  Class: bus              AP:   0.0281  -------
# -------  Class: car              AP:   0.1085  -------
# -------  Class: cat              AP:   0.0973  -------
# -------  Class: chair            AP:   0.1185  -------
# -------  Class: cow              AP:   0.0342  -------
# -------  Class: diningtable      AP:   0.0523  -------
# -------  Class: dog              AP:   0.1162  -------
# -------  Class: horse            AP:   0.0478  -------
# -------  Class: motorbike        AP:   0.0369  -------
# -------  Class: person           AP:   0.3754  -------
# -------  Class: pottedplant      AP:   0.0442  -------
# -------  Class: sheep            AP:   0.0367  -------
# -------  Class: sofa             AP:   0.0972  -------
# -------  Class: train            AP:   0.0390  -------
# -------  Class: tvmonitor        AP:   0.0484  -------
# mAP: 0.0843
# Avg loss: 0.24255542720065398
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08425557760114671
# Epcoh complete in 1m 1s
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.24234776198863983
# Epcoh complete in 0m 20s
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.23779645562171936
# Epcoh complete in 0m 21s
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.23164908587932587
# Epcoh complete in 0m 20s
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.22752271592617035
# -------  Class: aeroplane        AP:   0.3600  -------
# -------  Class: bicycle          AP:   0.0696  -------
# -------  Class: bird             AP:   0.1068  -------
# -------  Class: boat             AP:   0.2199  -------
# -------  Class: bottle           AP:   0.0766  -------
# -------  Class: bus              AP:   0.0645  -------
# -------  Class: car              AP:   0.2072  -------
# -------  Class: cat              AP:   0.1493  -------
# -------  Class: chair            AP:   0.2013  -------
# -------  Class: cow              AP:   0.0529  -------
# -------  Class: diningtable      AP:   0.1244  -------
# -------  Class: dog              AP:   0.1404  -------
# -------  Class: horse            AP:   0.0793  -------
# -------  Class: motorbike        AP:   0.0564  -------
# -------  Class: person           AP:   0.5312  -------
# -------  Class: pottedplant      AP:   0.0780  -------
# -------  Class: sheep            AP:   0.0516  -------
# -------  Class: sofa             AP:   0.1531  -------
# -------  Class: train            AP:   0.1522  -------
# -------  Class: tvmonitor        AP:   0.0602  -------
# mAP: 0.1467
# Avg loss: 0.22386138520988763
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.14673703552669703
# Epcoh complete in 1m 3s
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.22273457050323486
# Epcoh complete in 0m 21s
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.21914495527744293
# Epcoh complete in 0m 21s
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.21421833336353302
# Epcoh complete in 0m 21s
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.21496087312698364
# Epcoh complete in 0m 21s
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.20472796261310577
# -------  Class: aeroplane        AP:   0.5118  -------
# -------  Class: bicycle          AP:   0.1660  -------
# -------  Class: bird             AP:   0.1195  -------
# -------  Class: boat             AP:   0.1886  -------
# -------  Class: bottle           AP:   0.1052  -------
# -------  Class: bus              AP:   0.0930  -------
# -------  Class: car              AP:   0.4061  -------
# -------  Class: cat              AP:   0.1828  -------
# -------  Class: chair            AP:   0.2838  -------
# -------  Class: cow              AP:   0.0791  -------
# -------  Class: diningtable      AP:   0.1634  -------
# -------  Class: dog              AP:   0.1806  -------
# -------  Class: horse            AP:   0.1428  -------
# -------  Class: motorbike        AP:   0.1709  -------
# -------  Class: person           AP:   0.5751  -------
# -------  Class: pottedplant      AP:   0.0910  -------
# -------  Class: sheep            AP:   0.0398  -------
# -------  Class: sofa             AP:   0.1961  -------
# -------  Class: train            AP:   0.1820  -------
# -------  Class: tvmonitor        AP:   0.1150  -------
# mAP: 0.1996
# Avg loss: 0.2256088093215344
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.1996288634353315
# Epcoh complete in 1m 1s
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.2077573537826538
# Epcoh complete in 0m 20s
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.2060614675283432
# Epcoh complete in 0m 20s
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.19884070754051208
# Epcoh complete in 0m 20s
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.1932973712682724
# Epcoh complete in 0m 20s
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.19006559252738953
# -------  Class: aeroplane        AP:   0.5162  -------
# -------  Class: bicycle          AP:   0.2009  -------
# -------  Class: bird             AP:   0.1817  -------
# -------  Class: boat             AP:   0.2423  -------
# -------  Class: bottle           AP:   0.1192  -------
# -------  Class: bus              AP:   0.1317  -------
# -------  Class: car              AP:   0.5137  -------
# -------  Class: cat              AP:   0.2976  -------
# -------  Class: chair            AP:   0.3288  -------
# -------  Class: cow              AP:   0.1257  -------
# -------  Class: diningtable      AP:   0.2235  -------
# -------  Class: dog              AP:   0.1976  -------
# -------  Class: horse            AP:   0.3533  -------
# -------  Class: motorbike        AP:   0.2686  -------
# -------  Class: person           AP:   0.6414  -------
# -------  Class: pottedplant      AP:   0.1290  -------
# -------  Class: sheep            AP:   0.0903  -------
# -------  Class: sofa             AP:   0.2614  -------
# -------  Class: train            AP:   0.2612  -------
# -------  Class: tvmonitor        AP:   0.1708  -------
# mAP: 0.2628
# Avg loss: 0.20419801625550962
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.26275219415426754
# Epcoh complete in 1m 1s
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.18510843813419342
# Epcoh complete in 0m 20s
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.1868109256029129
# Epcoh complete in 0m 20s
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.1847836822271347
# Epcoh complete in 0m 20s
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.1812925785779953
# Epcoh complete in 0m 20s
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.17365321516990662
# -------  Class: aeroplane        AP:   0.5809  -------
# -------  Class: bicycle          AP:   0.2312  -------
# -------  Class: bird             AP:   0.1861  -------
# -------  Class: boat             AP:   0.2915  -------
# -------  Class: bottle           AP:   0.1153  -------
# -------  Class: bus              AP:   0.1307  -------
# -------  Class: car              AP:   0.4947  -------
# -------  Class: cat              AP:   0.2501  -------
# -------  Class: chair            AP:   0.3024  -------
# -------  Class: cow              AP:   0.0996  -------
# -------  Class: diningtable      AP:   0.1522  -------
# -------  Class: dog              AP:   0.1837  -------
# -------  Class: horse            AP:   0.3598  -------
# -------  Class: motorbike        AP:   0.3063  -------
# -------  Class: person           AP:   0.6279  -------
# -------  Class: pottedplant      AP:   0.1734  -------
# -------  Class: sheep            AP:   0.0969  -------
# -------  Class: sofa             AP:   0.2074  -------
# -------  Class: train            AP:   0.2525  -------
# -------  Class: tvmonitor        AP:   0.1993  -------
# mAP: 0.2621
# Avg loss: 0.22339433227099625
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.26209977154923664
# Epcoh complete in 1m 1s

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.5599  -------
# -------  Class: bicycle          AP:   0.2161  -------
# -------  Class: bird             AP:   0.1768  -------
# -------  Class: boat             AP:   0.2162  -------
# -------  Class: bottle           AP:   0.1291  -------
# -------  Class: bus              AP:   0.1347  -------
# -------  Class: car              AP:   0.5159  -------
# -------  Class: cat              AP:   0.2216  -------
# -------  Class: chair            AP:   0.2823  -------
# -------  Class: cow              AP:   0.1443  -------
# -------  Class: diningtable      AP:   0.1655  -------
# -------  Class: dog              AP:   0.1701  -------
# -------  Class: horse            AP:   0.4747  -------
# -------  Class: motorbike        AP:   0.2746  -------
# -------  Class: person           AP:   0.6406  -------
# -------  Class: pottedplant      AP:   0.1378  -------
# -------  Class: sheep            AP:   0.1657  -------
# -------  Class: sofa             AP:   0.2273  -------
# -------  Class: train            AP:   0.3289  -------
# -------  Class: tvmonitor        AP:   0.1375  -------
# mAP: 0.2660
# Avg loss: 0.21975834906101227
# Test mAP:  0.2659931264267922

# %% [markdown]
# You should notice somewhat poor performance. You could try running AlexNet with an Adam optimizer instead with learning rate 1e-4 to see if that makes a difference. This experiment is not required for the writeup, but it may show you the importance of a good learning rate and optimizer.

# %% [markdown]
# ## Pretrained AlexNet

# %% [markdown]
# Here we look at the impact of pretrained features. This model's weights were trained on ImageNet, which is a much larger dataset. How do pretrained features perform on VOC? Why do you think there is such a large difference in performance?

# %%
num_epochs = 20
test_frequency = 5

# Load Pretrained AlexNet
classifier = torchvision.models.alexnet(pretrained=True)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)
# optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.20358967781066895
# -------  Class: aeroplane        AP:   0.7436  -------
# -------  Class: bicycle          AP:   0.6003  -------
# -------  Class: bird             AP:   0.7870  -------
# -------  Class: boat             AP:   0.5898  -------
# -------  Class: bottle           AP:   0.2719  -------
# -------  Class: bus              AP:   0.5512  -------
# -------  Class: car              AP:   0.7539  -------
# -------  Class: cat              AP:   0.6934  -------
# -------  Class: chair            AP:   0.5985  -------
# -------  Class: cow              AP:   0.2413  -------
# -------  Class: diningtable      AP:   0.4905  -------
# -------  Class: dog              AP:   0.5488  -------
# -------  Class: horse            AP:   0.6338  -------
# -------  Class: motorbike        AP:   0.6605  -------
# -------  Class: person           AP:   0.8854  -------
# -------  Class: pottedplant      AP:   0.3390  -------
# -------  Class: sheep            AP:   0.4009  -------
# -------  Class: sofa             AP:   0.4525  -------
# -------  Class: train            AP:   0.8131  -------
# -------  Class: tvmonitor        AP:   0.5870  -------
# mAP: 0.5821
# Avg loss: 0.1381643614640423
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.5821261447885974
# Epcoh complete in 1m 12s
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.11452305316925049
# Epcoh complete in 0m 24s
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.08633942902088165
# Epcoh complete in 0m 23s
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.064329132437706
# Epcoh complete in 0m 23s
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.040131520479917526
# -------  Class: aeroplane        AP:   0.8572  -------
# -------  Class: bicycle          AP:   0.7214  -------
# -------  Class: bird             AP:   0.8466  -------
# -------  Class: boat             AP:   0.7618  -------
# -------  Class: bottle           AP:   0.3178  -------
# -------  Class: bus              AP:   0.5537  -------
# -------  Class: car              AP:   0.7937  -------
# -------  Class: cat              AP:   0.7946  -------
# -------  Class: chair            AP:   0.6007  -------
# -------  Class: cow              AP:   0.4683  -------
# -------  Class: diningtable      AP:   0.5946  -------
# -------  Class: dog              AP:   0.6931  -------
# -------  Class: horse            AP:   0.7442  -------
# -------  Class: motorbike        AP:   0.7936  -------
# -------  Class: person           AP:   0.9079  -------
# -------  Class: pottedplant      AP:   0.4658  -------
# -------  Class: sheep            AP:   0.5793  -------
# -------  Class: sofa             AP:   0.5134  -------
# -------  Class: train            AP:   0.8887  -------
# -------  Class: tvmonitor        AP:   0.6322  -------
# mAP: 0.6764
# Avg loss: 0.13610488833749995
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.676431524583584
# Epcoh complete in 1m 10s
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.02854309044778347
# Epcoh complete in 0m 25s
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.019581904634833336
# Epcoh complete in 0m 23s
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.0328499861061573
# Epcoh complete in 0m 23s
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.011262419633567333
# Epcoh complete in 0m 23s
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.007116287015378475
# -------  Class: aeroplane        AP:   0.8487  -------
# -------  Class: bicycle          AP:   0.7193  -------
# -------  Class: bird             AP:   0.8352  -------
# -------  Class: boat             AP:   0.7396  -------
# -------  Class: bottle           AP:   0.3483  -------
# -------  Class: bus              AP:   0.5901  -------
# -------  Class: car              AP:   0.8101  -------
# -------  Class: cat              AP:   0.7894  -------
# -------  Class: chair            AP:   0.5909  -------
# -------  Class: cow              AP:   0.4932  -------
# -------  Class: diningtable      AP:   0.6257  -------
# -------  Class: dog              AP:   0.6811  -------
# -------  Class: horse            AP:   0.7278  -------
# -------  Class: motorbike        AP:   0.8141  -------
# -------  Class: person           AP:   0.9040  -------
# -------  Class: pottedplant      AP:   0.4485  -------
# -------  Class: sheep            AP:   0.5544  -------
# -------  Class: sofa             AP:   0.4995  -------
# -------  Class: train            AP:   0.8856  -------
# -------  Class: tvmonitor        AP:   0.6254  -------
# mAP: 0.6766
# Avg loss: 0.18506654673347286
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.67655575945777
# Epcoh complete in 1m 8s
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.006332444958388805
# Epcoh complete in 0m 23s
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.005756155587732792
# Epcoh complete in 0m 23s
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.005418085027486086
# Epcoh complete in 0m 23s
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.006085370201617479
# Epcoh complete in 0m 23s
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.0036626236978918314
# -------  Class: aeroplane        AP:   0.8486  -------
# -------  Class: bicycle          AP:   0.6937  -------
# -------  Class: bird             AP:   0.8301  -------
# -------  Class: boat             AP:   0.7345  -------
# -------  Class: bottle           AP:   0.3362  -------
# -------  Class: bus              AP:   0.5643  -------
# -------  Class: car              AP:   0.8061  -------
# -------  Class: cat              AP:   0.7819  -------
# -------  Class: chair            AP:   0.5832  -------
# -------  Class: cow              AP:   0.4615  -------
# -------  Class: diningtable      AP:   0.6019  -------
# -------  Class: dog              AP:   0.6910  -------
# -------  Class: horse            AP:   0.7453  -------
# -------  Class: motorbike        AP:   0.8063  -------
# -------  Class: person           AP:   0.9025  -------
# -------  Class: pottedplant      AP:   0.4540  -------
# -------  Class: sheep            AP:   0.5471  -------
# -------  Class: sofa             AP:   0.5266  -------
# -------  Class: train            AP:   0.8787  -------
# -------  Class: tvmonitor        AP:   0.6102  -------
# mAP: 0.6702
# Avg loss: 0.22234424437377967
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.6701872109069432
# Epcoh complete in 1m 10s
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.007842283695936203
# Epcoh complete in 0m 23s
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.005399480927735567
# Epcoh complete in 0m 23s
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.012415505014359951
# Epcoh complete in 0m 23s
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.004302480258047581
# Epcoh complete in 0m 23s
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.00590471550822258
# -------  Class: aeroplane        AP:   0.8631  -------
# -------  Class: bicycle          AP:   0.6921  -------
# -------  Class: bird             AP:   0.8185  -------
# -------  Class: boat             AP:   0.7376  -------
# -------  Class: bottle           AP:   0.2848  -------
# -------  Class: bus              AP:   0.6139  -------
# -------  Class: car              AP:   0.7865  -------
# -------  Class: cat              AP:   0.7757  -------
# -------  Class: chair            AP:   0.5578  -------
# -------  Class: cow              AP:   0.5013  -------
# -------  Class: diningtable      AP:   0.5654  -------
# -------  Class: dog              AP:   0.7301  -------
# -------  Class: horse            AP:   0.7414  -------
# -------  Class: motorbike        AP:   0.7814  -------
# -------  Class: person           AP:   0.9004  -------
# -------  Class: pottedplant      AP:   0.4177  -------
# -------  Class: sheep            AP:   0.6181  -------
# -------  Class: sofa             AP:   0.5472  -------
# -------  Class: train            AP:   0.8715  -------
# -------  Class: tvmonitor        AP:   0.6144  -------
# mAP: 0.6709
# Avg loss: 0.21060999117645562
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.6709419832071644
# Epcoh complete in 1m 8s

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.8561  -------
# -------  Class: bicycle          AP:   0.7200  -------
# -------  Class: bird             AP:   0.7885  -------
# -------  Class: boat             AP:   0.7629  -------
# -------  Class: bottle           AP:   0.3139  -------
# -------  Class: bus              AP:   0.6855  -------
# -------  Class: car              AP:   0.8220  -------
# -------  Class: cat              AP:   0.7585  -------
# -------  Class: chair            AP:   0.5640  -------
# -------  Class: cow              AP:   0.4199  -------
# -------  Class: diningtable      AP:   0.6152  -------
# -------  Class: dog              AP:   0.7168  -------
# -------  Class: horse            AP:   0.8406  -------
# -------  Class: motorbike        AP:   0.7426  -------
# -------  Class: person           AP:   0.9153  -------
# -------  Class: pottedplant      AP:   0.4243  -------
# -------  Class: sheep            AP:   0.6105  -------
# -------  Class: sofa             AP:   0.4854  -------
# -------  Class: train            AP:   0.8606  -------
# -------  Class: tvmonitor        AP:   0.6417  -------
# mAP: 0.6772
# Avg loss: 0.2048172066360712
# Test mAP:  0.6772179569375825
